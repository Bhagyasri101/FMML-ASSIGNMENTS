# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhagyasri101/FMML-ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 10:51:54--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   139MB/s    in 0.5s
#
# 2024-03-31 10:51:55 (139 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22994  1801.03222v1  This paper deals with inference and prediction...  stat
# 7466   1801.02124v1  This paper considers the problem of inverse re...  stat
# 3404   1611.09958v2  In order to study the application of artificia...  stat
# 12331  1711.09876v1  Complex architectures of biological neural cir...  stat
# 5193    1110.3076v1  We consider the problem of covariance matrix e...  stat
# ...             ...                                                ...   ...
# 14093  1709.06206v1  We present a new back propagation based traini...    cs
# 37854   0902.3619v4  The starting point of this article is the ques...  stat
# 35202  cs/0105036v2  The paper proposes a new knowledge representat...    cs
# 10928   1007.3622v4  Motivated by the unceasing interest in hidden ...  stat
# 19720   1109.6361v1  Multimodal conversational interfaces provide a...    cs
#
#                                                    title  year  \
# 22994  Multivariate Bayesian Structural Time Series M...  2018
# 7466   Competitive Multi-agent Inverse Reinforcement ...  2018
# 3404          Machine Learning for Dental Image Analysis  2016
# 12331  Context-modulation of hippocampal dynamics and...  2017
# 5193   Efficient Latent Variable Graphical Model Sele...  2011
# ...                                                  ...   ...
# 14093  Algorithm and Hardware Design of Discrete-Time...  2017
# 37854  Context tree selection and linguistic rhythm r...  2009
# 35202        Disjunctive Logic Programs with Inheritance  2001
# 10928  A generalized risk approach to path inference ...  2010
# 19720  Cognitive Principles in Robust Multimodal Inte...  2011
#
#                                                 keywords
# 22994  [inference, prediction, correlated, candidate,...
# 7466   [considers, reinforcement, stochastic, demonst...
# 3404   [application, artificial, intelligence, techno...
# 12331  [architectures, biological, processing, behavi...
# 5193   [covariance, estimation, variables, conditions...
# ...                                                  ...
# 14093  [propagation, algorithm, algorithms, binarized...
# 37854  [fingerprints, brazilian, portuguese, portugue...
# 35202  [knowledge, representation, disjunctive, progr...
# 10928  [motivated, unceasing, inference, primarily, f...
# 19720  [multimodal, conversational, interfaces, commu...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22994    [inference, prediction, correlated, candidate,...
# 7466     [considers, reinforcement, stochastic, demonst...
# 3404     [application, artificial, intelligence, techno...
# 12331    [architectures, biological, processing, behavi...
# 5193     [covariance, estimation, variables, conditions...
#                                ...
# 11925    [reinforcement, considered, interaction, envir...
# 601      [employing, character, recurrent, detection, c...
# 32001    [framework, supervised, clustering, encountere...
# 30803    [architecture, performance, benchmarks, differ...
# 15018    [multilingual, linguistic, maastricht, archite...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8779 words.
# Out of those 4559 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c19f876a-80cd-4272-8ce5-9cb6ecc6cb42" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c19f876a-80cd-4272-8ce5-9cb6ecc6cb42")) {                    Plotly.newPlot(                        "c19f876a-80cd-4272-8ce5-9cb6ecc6cb42",                        [{"x":["multivariate","investigate","univariate","available","properties","candidate","inference","prediction","outperforms","performance","simulation","components","independent","contemporaneous","regression","benchmark","flexibility","different","structural","estimation","correlated","portfolio","selection","financial","simulations","institutions","component","forecasting","correlations","empirical","overfitting","extensive","integrated","predictors","variations","extending","autoregressive","equilibrium","existence","adversarial","theoretical","introduce","demonstrate","algorithms","strategies","functions","approaches","experiments","reinforcement","demonstrations","representations","numerical","competitive","stochastic","algorithm","approximations","optimality","considers","objective","application","implement","technology","invariant","representative","gradients","intelligence","histogram","convolutional","cognition","panoramic","artificial","transform","radiographs","biological","processing","architectures","computation","sensitive","mechanism","motivation","contextual","behaviorally","modulation","consequences","implicated","knowledge","cognitive","hippocampus","hippocampal","constrained","information","formation","complexity","involving","tractable","decomposed","graphical","structure","efficient","significantly","concentration","marginalization","guaranteed","correlation","thousands","variables","expression","covariance","conditions","explained","directions","specified","intensive","supervision","difference","minimizers","principal","alternatives","auxiliary","presented","continuously","dimensional","reduction","dimension","continuum","generalizations","resulting","considered","unsupervised","classification","incorporate","discriminant","criterion","asymptotic","interesting","supervised","inconsistent","functional","quantified","responsibility","according","potential","recovered","subspaces","dimensions","techniques","applications","clustering","derivatives","algebraic","classifying","estimated","geometric","collection","automatically","initialization","iterative","factorization","homogeneous","correspondences","maximization","segmentation","minimizing","extensions","segmenting","expectation","polynomial","complement","represent","generalized","polynomials","optimally","challenges","furthermore","environments","processes","expressions","interests","infrastructure","regarding","ontological","profitability","combination","relationships","integration","inheritance","management","semantics","ontologies","seamlessly","expressing","executable","transparency","discussed","connection","optimization","situations","unexpected","evaluated","investigating"],"y":[23,125,6,287,198,40,216,240,257,866,73,106,137,1,108,202,28,806,74,209,25,7,164,11,34,1,107,17,19,139,12,171,47,12,67,27,8,11,25,100,166,346,579,558,99,236,423,634,110,7,234,79,100,112,803,35,27,36,146,256,73,59,66,29,35,94,36,370,10,2,131,74,2,45,279,105,142,65,104,21,49,0,7,18,1,347,36,2,2,52,680,17,260,40,27,8,61,356,400,276,15,3,31,69,21,108,44,29,133,15,35,40,23,51,58,1,45,38,19,192,14,166,109,70,2,10,167,115,127,525,66,19,59,24,66,162,18,40,10,4,111,154,14,21,41,382,398,136,8,12,43,74,69,65,180,20,72,48,19,19,29,212,44,44,26,30,56,19,105,67,10,20,124,189,61,97,29,17,15,37,9,2,132,74,49,6,49,108,27,14,15,4,7,62,36,287,60,6,145,13],"type":"bar"},{"x":["multivariate","investigate","univariate","available","properties" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4559,), (4559, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.82

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Generating</span> <span style=''>models</span> <span style=''>for</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.33714285714285713);'>representations</span> <br/><br/><span style=''>We</span> <span style=''>discuss</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>model</span> <span style=''>building</span> <span style=''>for</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.33714285714285713);'>representations</span> <span style=''>We</span> <span style=''>chose</span> <span style=''>Polish</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3421052631578947);'>illustrate</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.4999999999999999);'>discussion</span> <span style=''>because</span> <span style=''>it</span> <span style=''>has</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interesting</span> <span style=''>aspectual</span> <span style=''>system</span> <span style=''>but</span> <span style=''>the</span> <span style=''>points</span> <span style=''>we</span> <span style=''>wish</span> <span style=''>to</span> <span style=''>make</span> <span style=''>are</span> <span style=''>not</span> <span style=''>language</span> <span style=''>specific</span> <span style=''>Rather</span> <span style=''>our</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>develop</span> <span style='background-color:rgba(255, 0, 0, 0.30105263157894735);'>theoretical</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>tools</span> <span style=''>for</span> <span style=''>temporal</span> <span style=''>model</span> <span style=''>building</span> <span style=''>tasks</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.9636363636363636);'>semantics</span> <span style=''>To</span> <span style=''>this</span> <span style=''>end</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>first</span> <span style=''>order</span> <span style=''>theory</span> <span style=''>of</span> <span style=''>time</span> <span style=''>and</span> <span style=''>events</span> <span style=''>which</span> <span style=''>is</span> <span style=''>rich</span> <span style=''>enough</span> <span style=''>to</span> <span style=''>capture</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interesting</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>distinctions</span> <span style=''>and</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>takes</span> <span style=''>minimal</span> <span style=''>models</span> <span style=''>for</span> <span style=''>first</span> <span style=''>order</span> <span style=''>theories</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>systematically</span> <span style=''>attempts</span> <span style=''>to</span> <span style=''>perturb</span> <span style=''>their</span> <span style=''>temporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>component</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>non</span> <span style=''>minimal</span> <span style=''>but</span> <span style='background-color:rgba(0, 255, 0, 0.942857142857143);'>semantically</span> <span style='background-color:rgba(0, 255, 0, 0.31444759206798856);'>significant</span> <span style=''>models</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Discovering</span> <span style=''>shared</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>in</span> <span style=''>multiple</span> <span style=''>time</span> <span style=''>series</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>Bayesian</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploratory</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>time</span> <span style=''>series</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>focuses</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understanding</span> <span style=''>shared</span> <span style=''>features</span> <span style=''>in</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>time</span> <span style=''>series</span> <span style=''>that</span> <span style=''>exhibit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individual</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variability</span> <span style=''>Our</span> <span style=''>method</span> <span style=''>builds</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>latent</span> <span style=''>Diricihlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>allocation</span> <span style=''>(LDA)</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterize</span> <span style=''>each</span> <span style=''>series</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>switching</span> <span style=''>between</span> <span style=''>latent</span> <span style=''>topics</span> <span style=''>where</span> <span style=''>each</span> <span style=''>topic</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterized</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style=''>words</span> <span style=''>that</span> <span style=''>specify</span> <span style=''>the</span> <span style=''>series</span> <span style=''>dynamics</span> <span style=''>However</span> <span style=''>unlike</span> <span style=''>standard</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>of</span> <span style=''>LDA</span> <span style=''>we</span> <span style=''>discover</span> <span style=''>the</span> <span style=''>words</span> <span style=''>as</span> <span style=''>we</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>model</span> <span style=''>We</span> <span style=''>apply</span> <span style=''>this</span> <span style=''>model ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>McGan</span> <span style=''>Mean</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5572519083969465);'>Covariance</span> <span style=''>Feature</span> <span style=''>Matching</span> <span style=''>GAN</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>new</span> <span style=''>families</span> <span style=''>of</span> <span style=''>Integral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probability</span> <span style=''>Metrics</span> <span style=''>(IPM)</span> <span style=''>for</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Adversarial</span> <span style=''>Networks</span> <span style=''>(GAN)</span> <span style=''>Our</span> <span style=''>IPMs</span> <span style=''>are</span> <span style=''>based</span> <span style=''>on</span> <span style=''>matching</span> <span style='background-color:rgba(255, 0, 0, 0.369047619047619);'>statistics</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.31306990881458974);'>distributions</span> <span style=''>embedded</span> <span style=''>in</span> <span style=''>a</span> <span style=''>finite</span> <span style='background-color:rgba(255, 0, 0, 0.3805970149253732);'>dimensional</span> <span style=''>feature</span> <span style=''>space</span> <span style=''>Mean</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5572519083969465);'>covariance</span> <span style=''>feature</span> <span style=''>matching</span> <span style=''>IPMs</span> <span style=''>allow</span> <span style=''>for</span> <span style=''>stable</span> <span style=''>training</span> <span style=''>of</span> <span style=''>GANs</span> <span style=''>which</span> <span style=''>we</span> <span style=''>will</span> <span style=''>call</span> <span style=''>McGan</span> <span style=''>McGan</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizes</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>meaningful</span> <span style=''>loss</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.31306990881458974);'>distributions</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Diffusion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Representations</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Diffusion</span> <span style=''>Maps</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>is</span> <span style=''>a</span> <span style=''>kernel</span> <span style=''>based</span> <span style=''>method</span> <span style=''>for</span> <span style=''>manifold</span> <span style=''>learning</span> <span style=''>and</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>that</span> <span style=''>defines</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarities</span> <span style=''>by</span> <span style=''>imposing</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Markovian</span> <span style=''>process</span> <span style=''>on</span> <span style=''>the</span> <span style=''>given</span> <span style=''>dataset</span> <span style=''>Analysis</span> <span style=''>by</span> <span style=''>this</span> <span style=''>process</span> <span style=''>uncovers</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>in</span> <span style=''>the</span> <span style=''>data</span> <span style=''>Recently</span> <span style=''>it</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>suggested</span> <span style=''>to</span> <span style=''>replace</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>kernel</span> <span style=''>by</span> <span style=''>a</span> <span style=''>measure</span> <span style=''>based</span> <span style=''>kernel</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporates</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>about</span> <span style=''>the</span> <span style=''>density</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>Thus</span> <span style=''>the</span> <span style=''>manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>is</span> <span style=''>replaced</span> <span style=''>by</span> <span style=''>a</span> <span style=''>more</span> <span style=''>general</span> <span style=''>measure</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumption</span> <span style=''>The</span> <span style=''>measure</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>diffusion</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporates</span> <span style=''>two</span> <span style=''>separate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>The</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determines</span> <span style=''>a</span> <span style=''>measure</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlates</span> <span style=''>with</span> <span style=''>a</span> <span style=''>density</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represents</span> <span style=''>normal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>behaviors</span> <span style=''>and</span> <span style=''>patterns</span> <span style=''>in</span> <span style=''>the</span> <span style=''>data</span> <span style=''>The</span> <span style=''>second</span> <span s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12504478681476172)
# 	evaluation (0.09423145825868864)
# 	knowledge (0.12432819777857398)
# 	detection (0.1053385883195987)
# 	architecture (0.0906485130777499)
# 	segmentation (0.07595843783590112)
# 	information (0.24364027230383375)
# 	convolutional (0.13256897169473308)
# 	recognition (0.13113579362235758)
# 	different (0.2887853815836618)
#
# Some Statistics words are:
# 	algorithms (0.289198606271777)
# 	estimation (0.16575410652065703)
# 	stochastic (0.13240418118466898)
# 	theoretical (0.15380786460925833)
# 	algorithm (0.38576406172224986)
# 	distribution (0.17322050771528125)
# 	statistical (0.15778994524639123)
# 	inference (0.19263315082130414)
# 	dimensional (0.18417122946739672)
# 	regression (0.18616226978596317)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="87e7cf4c-3a70-4cec-b86e-2cceadd45b7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87e7cf4c-3a70-4cec-b86e-2cceadd45b7e")) {                    Plotly.newPlot(                        "87e7cf4c-3a70-4cec-b86e-2cceadd45b7e",                        [{"x":["multivariate","investigate","univariate","available","properties","candidate","inference","prediction","outperforms","performance","simulation","components","independent","contemporaneous","regression","benchmark","flexibility","different","structural","estimation","correlated","portfolio","selection","financial","simulations","institutions","component","forecasting","correlations","empirical","overfitting","extensive","integrated","predictors","variations","extending","autoregressive","equilibrium","existence","adversarial","theoretical","introduce","demonstrate","algorithms","strategies","functions","approaches","experiments","reinforcement","demonstrations","representations","numerical","competitive","stochastic","algorithm","approximations","optimality","considers","objective","application","implement","technology","invariant","representative","gradients","intelligence","histogram","convolutional","cognition","panoramic","artificial","transform","radiographs","biological","processing","architectures","computation","sensitive","mechanism","motivation","contextual","behaviorally","modulation","consequences","implicated","knowledge","cognitive","hippocampus","hippocampal","constrained","information","formation","complexity","involving","tractable","decomposed","graphical","structure","efficient","significantly","concentration","marginalization","guaranteed","correlation","thousands","variables","expression","covariance","conditions","explained","directions","specified","intensive","supervision","difference","minimizers","principal","alternatives","auxiliary","presented","continuously","dimensional","reduction","dimension","continuum","generalizations","resulting","considered","unsupervised","classification","incorporate","discriminant","criterion","asymptotic","interesting","supervised","inconsistent","functional","quantified","responsibility","according","potential","recovered","subspaces","dimensions","techniques","applications","clustering","derivatives","algebraic","classifying","estimated","geometric","collection","automatically","initialization","iterative","factorization","homogeneous","correspondences","maximization","segmentation","minimizing","extensions","segmenting","expectation","polynomial","complement","represent","generalized","polynomials","optimally","challenges","furthermore","environments","processes","expressions","interests","infrastructure","regarding","ontological","profitability","combination","relationships","integration","inheritance","management","semantics","ontologies","seamlessly","expressing","executable","transparency","discussed","connection","optimization","situations","unexpected","evaluated","investigating","addresses","investigated","technique","introducing","situation","generation","behaviors","parameters","surrogate","uncertain","environment","reliability","consistently","statistical","confidence","importantly","predicted","respectively","maintains","informativeness","representativeness","classifiers","evaluating","classifier","informative","maximizing","unlabeled","retraining","virtually","instances","labelling","perturbations","variances","usefulness","exponentially","superiority","uncertainty","requirement","promising","incorporating","compensate","syntactic","attentional","especially","transduction","translation","represents","definition","uncertainties","experimentally","subjective","certainty","underlying","epigenomics", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	behaviorally
# 	epigenomics
# 	hypernetwork
# 	ellipsoid
# 	cytometry
# 	demonstrably
# 	reparameterization
# 	rightarrow
# 	impressively
# 	hypersphere
# 	chemicals
# 	reparametrizations
# 	reparametrization
# 	tsybakovs
# 	regularised
# 	indistinguishable
# 	dermatological
# 	intimately
# 	heteroscedasticity
# 	thermostat
# Some words which never appear in Statistics papers:
# 	responsibility
# 	ontological
# 	profitability
# 	inheritance
# 	ontologies
# 	syntactic
# 	attentional
# 	transduction
# 	summarizer
# 	conferences
# 	assembling
# 	campaigns
# 	segmented
# 	supplementing
# 	conclusive
# 	covariant
# 	comprehensively
# 	researches
# 	judgement
# 	defeasible

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.079860790292279e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7766666666666666
